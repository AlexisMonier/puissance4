# %%
# !pip install puissance4
import puissance4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting puissance4
#   Downloading puissance4-0.6.1-py3-none-any.whl (22 kB)
# Installing collected packages: puissance4
# Successfully installed puissance4-0.6.1

# %%
puissance4.play_now()
# Out:
# [AI] symbol = X
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# Human player is O
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . . . . . .
# 5|. . . X . . .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:c
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . . . . . .
# 5|. . O X . . .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . . . . . .
# 5|. X O X . . .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:d
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . . O . . .
# 5|. X O X . . .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . . O . . .
# 5|. X O X . X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:e
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . . O . . .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . . . . . .
# 4|. . X O . . .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:c
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . . . . . .
# 3|. . O . . . .
# 4|. . X O . . .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, C) below.
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . . . .
# 3|. . O . . . .
# 4|. . X O . . .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:f
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . . . .
# 3|. . O . . . .
# 4|. . X O . O .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . . . .
# 3|. . O X . . .
# 4|. . X O . O .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:e
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . . . .
# 3|. . O X . . .
# 4|. . X O O O .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, E) below.
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . . . .
# 3|. . O X X . .
# 4|. . X O O O .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:e
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . O . .
# 3|. . O X X . .
# 4|. . X O O O .
# 5|. X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . O . .
# 3|. . O X X . .
# 4|. . X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:b
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . O . .
# 3|. . O X X . .
# 4|. O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . O . .
# 3|. . O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:a
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . O . .
# 3|O . O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|. . X . O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:a
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|O . X . O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, D) below.
#
# 0|. . . . . . .
# 1|. . . . . . .
# 2|O . X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:d
#
# 0|. . . . . . .
# 1|. . . O . . .
# 2|O . X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, B) below.
#
# 0|. . . . . . .
# 1|. . . O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:&
# Letter a through g  = drop disc, q = quit.
# Your move:a
#
# 0|. . . . . . .
# 1|O . . O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, A) below.
#
# 0|X . . . . . .
# 1|O . . O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:b
#
# 0|X . . . . . .
# 1|O O . O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, C) below.
#
# 0|X . . . . . .
# 1|O O X O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:d
#
# 0|X . . O . . .
# 1|O O X O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, C) below.
#
# 0|X . X O . . .
# 1|O O X O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:b
#
# 0|X O X O . . .
# 1|O O X O . . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|X O X O . . .
# 1|O O X O X . .
# 2|O X X X O . .
# 3|O X O X X . .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:f
#
# 0|X O X O . . .
# 1|O O X O X . .
# 2|O X X X O . .
# 3|O X O X X O .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|X O X O X . .
# 1|O O X O X . .
# 2|O X X X O . .
# 3|O X O X X O .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:f
#
# 0|X O X O X . .
# 1|O O X O X . .
# 2|O X X X O O .
# 3|O X O X X O .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Obvious play by AI in (X, F) below.
#
# 0|X O X O X . .
# 1|O O X O X X .
# 2|O X X X O O .
# 3|O X O X X O .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:f
#
# 0|X O X O X O .
# 1|O O X O X X .
# 2|O X X X O O .
# 3|O X O X X O .
# 4|X O X O O O .
# 5|X X O X O X .
#   - - - - - - -
#   A B C D E F G
#
#
# 0|X O X O X O .
# 1|O O X O X X .
# 2|O X X X O O .
# 3|O X O X X O .
# 4|X O X O O O .
# 5|X X O X O X X
#   - - - - - - -
#   A B C D E F G
#
# Letter a through g  = drop disc, q = quit.
# Your move:g
# Winner = O (human being) after 38 steps
#
# 0|X O X O X O .
# 1|O O X O X X .
# 2|O X X X O O .
# 3|O X O X X O .
# 4|X O X O O O O
# 5|X X O X O X X
#   - - - - - - -
#   A B C D E F G

# %%
import puissance4

# Either 'Random', 'MC' for Monte Carlo, or 'UCT' for Upper-Confidence bounds for Trees
trainer_choice = 'Random'

# Play 200 games in a setting UCT AI vs. trainer AI
puissance4.prepare_and_train(trainer_choice=trainer_choice, num_parties_jouees=200)
# Out:
# [AI] symbol = X
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# [AI] symbol = O
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
#
# Game n°1	num_steps = 29	winner = learner (X)
# Game n°2	num_steps = 19	winner = learner (X)
# Game n°3	num_steps = 11	winner = learner (X)
# Game n°4	num_steps = 17	winner = learner (X)
# Game n°5	num_steps = 17	winner = learner (X)
# Game n°6	num_steps = 23	winner = trainer (X)
# Game n°7	num_steps = 25	winner = learner (X)
# Game n°8	num_steps = 25	winner = learner (X)
# Game n°9	num_steps = 18	winner = learner (O)
# Game n°10	num_steps = 12	winner = learner (O)
# Game n°11	num_steps = 7	winner = trainer (X)
# Game n°12	num_steps = 9	winner = learner (X)
# Game n°13	num_steps = 35	winner = learner (X)
# Game n°14	num_steps = 27	winner = learner (X)
# Game n°15	num_steps = 19	winner = learner (X)
# Game n°16	num_steps = 16	winner = learner (O)
# Game n°17	num_steps = 14	winner = learner (O)
# Game n°18	num_steps = 17	winner = learner (X)
# Game n°19	num_steps = 15	winner = learner (X)
# Game n°20	num_steps = 25	winner = learner (X)
# Game n°21	num_steps = 17	winner = trainer (X)
# Game n°22	num_steps = 21	winner = learner (X)
# Game n°23	num_steps = 23	winner = learner (X)
# Game n°24	num_steps = 27	winner = learner (X)
# Game n°25	num_steps = 19	winner = learner (X)
# Game n°26	num_steps = 37	winner = learner (X)
# Game n°27	num_steps = 29	winner = learner (X)
# Game n°28	num_steps = 27	winner = learner (X)
# Game n°29	num_steps = 19	winner = learner (X)
# Game n°30	num_steps = 35	winner = learner (X)
# Game n°31	num_steps = 21	winner = trainer (X)
# Game n°32	num_steps = 42	winner = draw (draw)
# Game n°33	num_steps = 36	winner = learner (O)
# Game n°34	num_steps = 9	winner = learner (X)
# Game n°35	num_steps = 27	winner = trainer (X)
# Game n°36	num_steps = 24	winner = learner (O)
# Game n°37	num_steps = 42	winner = draw (draw)
# Game n°38	num_steps = 23	winner = trainer (X)
# Game n°39	num_steps = 32	winner = learner (O)
# Game n°40	num_steps = 26	winner = learner (O)
# Game n°41	num_steps = 28	winner = learner (O)
# Game n°42	num_steps = 21	winner = learner (X)
# Game n°43	num_steps = 14	winner = learner (O)
# Game n°44	num_steps = 37	winner = learner (X)
# Game n°45	num_steps = 23	winner = learner (X)
# Game n°46	num_steps = 27	winner = trainer (X)
# Game n°47	num_steps = 24	winner = trainer (O)
# Game n°48	num_steps = 29	winner = learner (X)
# Game n°49	num_steps = 23	winner = trainer (X)
# Game n°50	num_steps = 17	winner = trainer (X)
# Game n°51	num_steps = 38	winner = learner (O)
# Game n°52	num_steps = 21	winner = learner (X)
# Game n°53	num_steps = 27	winner = trainer (X)
# Game n°54	num_steps = 15	winner = trainer (X)
# Game n°55	num_steps = 27	winner = learner (X)
# Game n°56	num_steps = 15	winner = learner (X)
# Game n°57	num_steps = 23	winner = learner (X)
# Game n°58	num_steps = 26	winner = learner (O)
# Game n°59	num_steps = 22	winner = learner (O)
# Game n°60	num_steps = 20	winner = learner (O)
# Game n°61	num_steps = 20	winner = learner (O)
# Game n°62	num_steps = 21	winner = learner (X)
# Game n°63	num_steps = 9	winner = learner (X)
# Game n°64	num_steps = 13	winner = learner (X)
# Game n°65	num_steps = 38	winner = learner (O)
# Game n°66	num_steps = 14	winner = learner (O)
# Game n°67	num_steps = 27	winner = trainer (X)
# Game n°68	num_steps = 25	winner = learner (X)
# Game n°69	num_steps = 15	winner = learner (X)
# Game n°70	num_steps = 29	winner = learner (X)
# Game n°71	num_steps = 20	winner = learner (O)
# Game n°72	num_steps = 29	winner = learner (X)
# Game n°73	num_steps = 29	winner = trainer (X)
# Game n°74	num_steps = 33	winner = learner (X)
# Game n°75	num_steps = 27	winner = learner (X)
# Game n°76	num_steps = 24	winner = learner (O)
# Game n°77	num_steps = 18	winner = learner (O)
# Game n°78	num_steps = 23	winner = learner (X)
# Game n°79	num_steps = 24	winner = learner (O)
# Game n°80	num_steps = 17	winner = trainer (X)
# Game n°81	num_steps = 33	winner = learner (X)
# Game n°82	num_steps = 17	winner = trainer (X)
# Game n°83	num_steps = 19	winner = learner (X)
# Game n°84	num_steps = 21	winner = learner (X)
# Game n°85	num_steps = 28	winner = learner (O)
# Game n°86	num_steps = 17	winner = learner (X)
# Game n°87	num_steps = 26	winner = learner (O)
# Game n°88	num_steps = 11	winner = learner (X)
# Game n°89	num_steps = 9	winner = learner (X)
# Game n°90	num_steps = 21	winner = learner (X)
# Game n°91	num_steps = 16	winner = trainer (O)
# Game n°92	num_steps = 26	winner = learner (O)
# Game n°93	num_steps = 36	winner = learner (O)
# Game n°94	num_steps = 19	winner = trainer (X)
# Game n°95	num_steps = 24	winner = learner (O)
# Game n°96	num_steps = 17	winner = learner (X)
# Game n°97	num_steps = 23	winner = learner (X)
# Game n°98	num_steps = 19	winner = learner (X)
# Game n°99	num_steps = 27	winner = learner (X)
# Game n°100	num_steps = 18	winner = learner (O)
# Game n°101	num_steps = 13	winner = learner (X)
# Game n°102	num_steps = 12	winner = learner (O)
# Game n°103	num_steps = 22	winner = learner (O)
# Game n°104	num_steps = 31	winner = trainer (X)
# Game n°105	num_steps = 25	winner = learner (X)
# Game n°106	num_steps = 17	winner = learner (X)
# Game n°107	num_steps = 27	winner = learner (X)
# Game n°108	num_steps = 27	winner = learner (X)
# Game n°109	num_steps = 12	winner = learner (O)
# Game n°110	num_steps = 13	winner = learner (X)
# Game n°111	num_steps = 19	winner = learner (X)
# Game n°112	num_steps = 15	winner = learner (X)
# Game n°113	num_steps = 16	winner = learner (O)
# Game n°114	num_steps = 18	winner = learner (O)
# Game n°115	num_steps = 28	winner = learner (O)
# Game n°116	num_steps = 28	winner = learner (O)
# Game n°117	num_steps = 9	winner = learner (X)
# Game n°118	num_steps = 26	winner = learner (O)
# Game n°119	num_steps = 38	winner = trainer (O)
# Game n°120	num_steps = 19	winner = learner (X)
# Game n°121	num_steps = 14	winner = trainer (O)
# Game n°122	num_steps = 16	winner = learner (O)
# Game n°123	num_steps = 18	winner = learner (O)
# Game n°124	num_steps = 34	winner = learner (O)
# Game n°125	num_steps = 23	winner = trainer (X)
# Game n°126	num_steps = 20	winner = learner (O)
# Game n°127	num_steps = 22	winner = learner (O)
# Game n°128	num_steps = 30	winner = learner (O)
# Game n°129	num_steps = 21	winner = learner (X)
# Game n°130	num_steps = 19	winner = learner (X)
# Game n°131	num_steps = 24	winner = learner (O)
# Game n°132	num_steps = 24	winner = learner (O)
# Game n°133	num_steps = 20	winner = learner (O)
# Game n°134	num_steps = 19	winner = learner (X)
# Game n°135	num_steps = 16	winner = learner (O)
# Game n°136	num_steps = 23	winner = learner (X)
# Game n°137	num_steps = 17	winner = learner (X)
# Game n°138	num_steps = 23	winner = learner (X)
# Game n°139	num_steps = 18	winner = learner (O)
# Game n°140	num_steps = 19	winner = learner (X)
# Game n°141	num_steps = 15	winner = learner (X)
# Game n°142	num_steps = 15	winner = learner (X)
# Game n°143	num_steps = 26	winner = learner (O)
# Game n°144	num_steps = 27	winner = trainer (X)
# Game n°145	num_steps = 26	winner = learner (O)
# Game n°146	num_steps = 26	winner = learner (O)
# Game n°147	num_steps = 19	winner = learner (X)
# Game n°148	num_steps = 17	winner = learner (X)
# Game n°149	num_steps = 17	winner = learner (X)
# Game n°150	num_steps = 20	winner = learner (O)
# Game n°151	num_steps = 27	winner = learner (X)
# Game n°152	num_steps = 20	winner = learner (O)
# Game n°153	num_steps = 25	winner = learner (X)
# Game n°154	num_steps = 25	winner = learner (X)
# Game n°155	num_steps = 20	winner = learner (O)
# Game n°156	num_steps = 24	winner = trainer (O)
# Game n°157	num_steps = 9	winner = learner (X)
# Game n°158	num_steps = 17	winner = learner (X)
# Game n°159	num_steps = 19	winner = learner (X)
# Game n°160	num_steps = 37	winner = learner (X)
# Game n°161	num_steps = 18	winner = learner (O)
# Game n°162	num_steps = 23	winner = trainer (X)
# Game n°163	num_steps = 19	winner = learner (X)
# Game n°164	num_steps = 21	winner = learner (X)
# Game n°165	num_steps = 40	winner = learner (O)
# Game n°166	num_steps = 26	winner = trainer (O)
# Game n°167	num_steps = 21	winner = learner (X)
# Game n°168	num_steps = 18	winner = learner (O)
# Game n°169	num_steps = 17	winner = learner (X)
# Game n°170	num_steps = 17	winner = learner (X)
# Game n°171	num_steps = 23	winner = learner (X)
# Game n°172	num_steps = 32	winner = learner (O)
# Game n°173	num_steps = 21	winner = learner (X)
# Game n°174	num_steps = 37	winner = trainer (X)
# Game n°175	num_steps = 14	winner = learner (O)
# Game n°176	num_steps = 23	winner = learner (X)
# Game n°177	num_steps = 25	winner = trainer (X)
# Game n°178	num_steps = 21	winner = learner (X)
# Game n°179	num_steps = 28	winner = learner (O)
# Game n°180	num_steps = 37	winner = learner (X)
# Game n°181	num_steps = 26	winner = learner (O)
# Game n°182	num_steps = 32	winner = learner (O)
# Game n°183	num_steps = 27	winner = learner (X)
# Game n°184	num_steps = 42	winner = draw (draw)
# Game n°185	num_steps = 32	winner = learner (O)
# Game n°186	num_steps = 26	winner = learner (O)
# Game n°187	num_steps = 21	winner = learner (X)
# Game n°188	num_steps = 15	winner = learner (X)
# Game n°189	num_steps = 18	winner = learner (O)
# Game n°190	num_steps = 21	winner = learner (X)
# Game n°191	num_steps = 35	winner = learner (X)
# Game n°192	num_steps = 41	winner = learner (X)
# Game n°193	num_steps = 22	winner = learner (O)
# Game n°194	num_steps = 25	winner = trainer (X)
# Game n°195	num_steps = 25	winner = learner (X)
# Game n°196	num_steps = 28	winner = learner (O)
# Game n°197	num_steps = 28	winner = learner (O)
# Game n°198	num_steps = 23	winner = learner (X)
# Game n°199	num_steps = 19	winner = trainer (X)
# Game n°200	num_steps = 21	winner = learner (X)
#
# [AI] symbol = X
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# [Players X vs. O] winrate = 0.63 (over 200 games)
#
# [Learner vs. Trainer] winrate = 0.84 (over 200 games)
#
# {'draw': 3, ('learner', 'X'): 101, ('learner', 'O'): 66, ('trainer', 'X'): 24, ('trainer', 'O'): 6}
# {'X': 125, 'O': 72, 'draw': 3}
# {'learner': 167, 'trainer': 30, 'draw': 3}
# (True,
#  {'draw': 3,
#   ('learner', 'X'): 101,
#   ('learner', 'O'): 66,
#   ('trainer', 'X'): 24,
#   ('trainer', 'O'): 6},
#  [29,
#   19,
#   11,
#   17,
#   17,
#   23,
#   25,
#   25,
#   18,
#   12,
#   7,
#   9,
#   35,
#   27,
#   19,
#   16,
#   14,
#   17,
#   15,
#   25,
#   17,
#   21,
#   23,
#   27,
#   19,
#   37,
#   29,
#   27,
#   19,
#   35,
#   21,
#   42,
#   36,
#   9,
#   27,
#   24,
#   42,
#   23,
#   32,
#   26,
#   28,
#   21,
#   14,
#   37,
#   23,
#   27,
#   24,
#   29,
#   23,
#   17,
#   38,
#   21,
#   27,
#   15,
#   27,
#   15,
#   23,
#   26,
#   22,
#   20,
#   20,
#   21,
#   9,
#   13,
#   38,
#   14,
#   27,
#   25,
#   15,
#   29,
#   20,
#   29,
#   29,
#   33,
#   27,
#   24,
#   18,
#   23,
#   24,
#   17,
#   33,
#   17,
#   19,
#   21,
#   28,
#   17,
#   26,
#   11,
#   9,
#   21,
#   16,
#   26,
#   36,
#   19,
#   24,
#   17,
#   23,
#   19,
#   27,
#   18,
#   13,
#   12,
#   22,
#   31,
#   25,
#   17,
#   27,
#   27,
#   12,
#   13,
#   19,
#   15,
#   16,
#   18,
#   28,
#   28,
#   9,
#   26,
#   38,
#   19,
#   14,
#   16,
#   18,
#   34,
#   23,
#   20,
#   22,
#   30,
#   21,
#   19,
#   24,
#   24,
#   20,
#   19,
#   16,
#   23,
#   17,
#   23,
#   18,
#   19,
#   15,
#   15,
#   26,
#   27,
#   26,
#   26,
#   19,
#   17,
#   17,
#   20,
#   27,
#   20,
#   25,
#   25,
#   20,
#   24,
#   9,
#   17,
#   19,
#   37,
#   18,
#   23,
#   19,
#   21,
#   40,
#   26,
#   21,
#   18,
#   17,
#   17,
#   23,
#   32,
#   21,
#   37,
#   14,
#   23,
#   25,
#   21,
#   28,
#   37,
#   26,
#   32,
#   27,
#   42,
#   32,
#   26,
#   21,
#   15,
#   18,
#   21,
#   35,
#   41,
#   22,
#   25,
#   25,
#   28,
#   28,
#   23,
#   19,
#   21])

# %%
# Either 'Random', 'MC' for Monte Carlo, or 'UCT' for Upper-Confidence bounds for Trees
trainer_choice = 'MC'

# Play 200 games in a setting UCT AI vs. trainer AI
puissance4.prepare_and_train(trainer_choice=trainer_choice, num_parties_jouees=200)
# Out:
# [AI] symbol = X
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# [AI] symbol = O
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 56
# [Monte Carlo] deterministic strategy for action sampling at the root = True
#
# Game n°1	num_steps = 21	winner = learner (X)
# Game n°2	num_steps = 21	winner = learner (X)
# Game n°3	num_steps = 23	winner = learner (X)
# Game n°4	num_steps = 28	winner = trainer (O)
# Game n°5	num_steps = 27	winner = trainer (X)
# Game n°6	num_steps = 11	winner = trainer (X)
# Game n°7	num_steps = 38	winner = trainer (O)
# Game n°8	num_steps = 15	winner = learner (X)
# Game n°9	num_steps = 27	winner = trainer (X)
# Game n°10	num_steps = 18	winner = learner (O)
# Game n°11	num_steps = 19	winner = trainer (X)
# Game n°12	num_steps = 22	winner = trainer (O)
# Game n°13	num_steps = 17	winner = learner (X)
# Game n°14	num_steps = 15	winner = learner (X)
# Game n°15	num_steps = 15	winner = learner (X)
# Game n°16	num_steps = 22	winner = trainer (O)
# Game n°17	num_steps = 21	winner = trainer (X)
# Game n°18	num_steps = 27	winner = trainer (X)
# Game n°19	num_steps = 18	winner = learner (O)
# Game n°20	num_steps = 11	winner = trainer (X)
# Game n°21	num_steps = 29	winner = trainer (X)
# Game n°22	num_steps = 17	winner = learner (X)
# Game n°23	num_steps = 15	winner = learner (X)
# Game n°24	num_steps = 13	winner = learner (X)
# Game n°25	num_steps = 17	winner = trainer (X)
# Game n°26	num_steps = 18	winner = learner (O)
# Game n°27	num_steps = 25	winner = learner (X)
# Game n°28	num_steps = 29	winner = learner (X)
# Game n°29	num_steps = 20	winner = learner (O)
# Game n°30	num_steps = 33	winner = trainer (X)
# Game n°31	num_steps = 42	winner = draw (draw)
# Game n°32	num_steps = 16	winner = learner (O)
# Game n°33	num_steps = 16	winner = learner (O)
# Game n°34	num_steps = 25	winner = learner (X)
# Game n°35	num_steps = 15	winner = trainer (X)
# Game n°36	num_steps = 13	winner = learner (X)
# Game n°37	num_steps = 19	winner = learner (X)
# Game n°38	num_steps = 13	winner = learner (X)
# Game n°39	num_steps = 19	winner = trainer (X)
# Game n°40	num_steps = 16	winner = learner (O)
# Game n°41	num_steps = 16	winner = learner (O)
# Game n°42	num_steps = 17	winner = trainer (X)
# Game n°43	num_steps = 7	winner = trainer (X)
# Game n°44	num_steps = 18	winner = learner (O)
# Game n°45	num_steps = 20	winner = trainer (O)
# Game n°46	num_steps = 17	winner = learner (X)
# Game n°47	num_steps = 7	winner = trainer (X)
# Game n°48	num_steps = 18	winner = learner (O)
# Game n°49	num_steps = 13	winner = learner (X)
# Game n°50	num_steps = 25	winner = trainer (X)
# Game n°51	num_steps = 33	winner = learner (X)
# Game n°52	num_steps = 22	winner = trainer (O)
# Game n°53	num_steps = 38	winner = trainer (O)
# Game n°54	num_steps = 21	winner = learner (X)
# Game n°55	num_steps = 13	winner = learner (X)
# Game n°56	num_steps = 15	winner = learner (X)
# Game n°57	num_steps = 21	winner = learner (X)
# Game n°58	num_steps = 15	winner = learner (X)
# Game n°59	num_steps = 22	winner = trainer (O)
# Game n°60	num_steps = 20	winner = learner (O)
# Game n°61	num_steps = 18	winner = learner (O)
# Game n°62	num_steps = 13	winner = learner (X)
# Game n°63	num_steps = 29	winner = trainer (X)
# Game n°64	num_steps = 15	winner = trainer (X)
# Game n°65	num_steps = 9	winner = learner (X)
# Game n°66	num_steps = 13	winner = learner (X)
# Game n°67	num_steps = 25	winner = trainer (X)
# Game n°68	num_steps = 26	winner = learner (O)
# Game n°69	num_steps = 18	winner = learner (O)
# Game n°70	num_steps = 23	winner = learner (X)
# Game n°71	num_steps = 29	winner = learner (X)
# Game n°72	num_steps = 13	winner = learner (X)
# Game n°73	num_steps = 26	winner = trainer (O)
# Game n°74	num_steps = 20	winner = learner (O)
# Game n°75	num_steps = 19	winner = learner (X)
# Game n°76	num_steps = 37	winner = trainer (X)
# Game n°77	num_steps = 23	winner = trainer (X)
# Game n°78	num_steps = 17	winner = learner (X)
# Game n°79	num_steps = 14	winner = trainer (O)
# Game n°80	num_steps = 19	winner = trainer (X)
# Game n°81	num_steps = 23	winner = trainer (X)
# Game n°82	num_steps = 25	winner = trainer (X)
# Game n°83	num_steps = 13	winner = learner (X)
# Game n°84	num_steps = 13	winner = learner (X)
# Game n°85	num_steps = 17	winner = learner (X)
# Game n°86	num_steps = 24	winner = trainer (O)
# Game n°87	num_steps = 32	winner = trainer (O)
# Game n°88	num_steps = 22	winner = learner (O)
# Game n°89	num_steps = 21	winner = learner (X)
# Game n°90	num_steps = 15	winner = learner (X)
# Game n°91	num_steps = 17	winner = learner (X)
# Game n°92	num_steps = 28	winner = trainer (O)
# Game n°93	num_steps = 15	winner = trainer (X)
# Game n°94	num_steps = 19	winner = trainer (X)
# Game n°95	num_steps = 18	winner = trainer (O)
# Game n°96	num_steps = 26	winner = trainer (O)
# Game n°97	num_steps = 31	winner = trainer (X)
# Game n°98	num_steps = 22	winner = learner (O)
# Game n°99	num_steps = 26	winner = learner (O)
# Game n°100	num_steps = 15	winner = trainer (X)
# Game n°101	num_steps = 25	winner = trainer (X)
# Game n°102	num_steps = 24	winner = trainer (O)
# Game n°103	num_steps = 16	winner = learner (O)
# Game n°104	num_steps = 17	winner = trainer (X)
# Game n°105	num_steps = 22	winner = learner (O)
# Game n°106	num_steps = 12	winner = learner (O)
# Game n°107	num_steps = 18	winner = trainer (O)
# Game n°108	num_steps = 15	winner = trainer (X)
# Game n°109	num_steps = 14	winner = learner (O)
# Game n°110	num_steps = 29	winner = learner (X)
# Game n°111	num_steps = 36	winner = trainer (O)
# Game n°112	num_steps = 21	winner = trainer (X)
# Game n°113	num_steps = 33	winner = trainer (X)
# Game n°114	num_steps = 7	winner = trainer (X)
# Game n°115	num_steps = 21	winner = trainer (X)
# Game n°116	num_steps = 21	winner = trainer (X)
# Game n°117	num_steps = 17	winner = trainer (X)
# Game n°118	num_steps = 22	winner = trainer (O)
# Game n°119	num_steps = 17	winner = learner (X)
# Game n°120	num_steps = 24	winner = learner (O)
# Game n°121	num_steps = 22	winner = learner (O)
# Game n°122	num_steps = 8	winner = trainer (O)
# Game n°123	num_steps = 32	winner = trainer (O)
# Game n°124	num_steps = 11	winner = trainer (X)
# Game n°125	num_steps = 30	winner = trainer (O)
# Game n°126	num_steps = 7	winner = trainer (X)
# Game n°127	num_steps = 7	winner = trainer (X)
# Game n°128	num_steps = 13	winner = trainer (X)
# Game n°129	num_steps = 31	winner = trainer (X)
# Game n°130	num_steps = 13	winner = learner (X)
# Game n°131	num_steps = 33	winner = learner (X)
# Game n°132	num_steps = 22	winner = learner (O)
# Game n°133	num_steps = 25	winner = learner (X)
# Game n°134	num_steps = 25	winner = trainer (X)
# Game n°135	num_steps = 17	winner = trainer (X)
# Game n°136	num_steps = 32	winner = learner (O)
# Game n°137	num_steps = 37	winner = learner (X)
# Game n°138	num_steps = 25	winner = trainer (X)
# Game n°139	num_steps = 21	winner = learner (X)
# Game n°140	num_steps = 39	winner = learner (X)
# Game n°141	num_steps = 30	winner = trainer (O)
# Game n°142	num_steps = 29	winner = trainer (X)
# Game n°143	num_steps = 27	winner = trainer (X)
# Game n°144	num_steps = 26	winner = learner (O)
# Game n°145	num_steps = 22	winner = trainer (O)
# Game n°146	num_steps = 20	winner = learner (O)
# Game n°147	num_steps = 7	winner = trainer (X)
# Game n°148	num_steps = 19	winner = trainer (X)
# Game n°149	num_steps = 12	winner = trainer (O)
# Game n°150	num_steps = 27	winner = trainer (X)
# Game n°151	num_steps = 15	winner = learner (X)
# Game n°152	num_steps = 19	winner = trainer (X)
# Game n°153	num_steps = 29	winner = learner (X)
# Game n°154	num_steps = 23	winner = trainer (X)
# Game n°155	num_steps = 34	winner = learner (O)
# Game n°156	num_steps = 42	winner = draw (draw)
# Game n°157	num_steps = 20	winner = trainer (O)
# Game n°158	num_steps = 17	winner = trainer (X)
# Game n°159	num_steps = 34	winner = trainer (O)
# Game n°160	num_steps = 27	winner = learner (X)
# Game n°161	num_steps = 26	winner = trainer (O)
# Game n°162	num_steps = 26	winner = learner (O)
# Game n°163	num_steps = 22	winner = trainer (O)
# Game n°164	num_steps = 25	winner = trainer (X)
# Game n°165	num_steps = 19	winner = learner (X)
# Game n°166	num_steps = 26	winner = learner (O)
# Game n°167	num_steps = 24	winner = trainer (O)
# Game n°168	num_steps = 13	winner = learner (X)
# Game n°169	num_steps = 25	winner = learner (X)
# Game n°170	num_steps = 19	winner = trainer (X)
# Game n°171	num_steps = 21	winner = trainer (X)
# Game n°172	num_steps = 29	winner = trainer (X)
# Game n°173	num_steps = 14	winner = trainer (O)
# Game n°174	num_steps = 22	winner = trainer (O)
# Game n°175	num_steps = 16	winner = trainer (O)
# Game n°176	num_steps = 19	winner = trainer (X)
# Game n°177	num_steps = 15	winner = learner (X)
# Game n°178	num_steps = 9	winner = trainer (X)
# Game n°179	num_steps = 22	winner = trainer (O)
# Game n°180	num_steps = 26	winner = learner (O)
# Game n°181	num_steps = 15	winner = trainer (X)
# Game n°182	num_steps = 16	winner = learner (O)
# Game n°183	num_steps = 20	winner = trainer (O)
# Game n°184	num_steps = 28	winner = trainer (O)
# Game n°185	num_steps = 7	winner = trainer (X)
# Game n°186	num_steps = 17	winner = trainer (X)
# Game n°187	num_steps = 7	winner = trainer (X)
# Game n°188	num_steps = 15	winner = trainer (X)
# Game n°189	num_steps = 19	winner = trainer (X)
# Game n°190	num_steps = 38	winner = trainer (O)
# Game n°191	num_steps = 23	winner = trainer (X)
# Game n°192	num_steps = 39	winner = learner (X)
# Game n°193	num_steps = 7	winner = learner (X)
# Game n°194	num_steps = 30	winner = trainer (O)
# Game n°195	num_steps = 28	winner = trainer (O)
# Game n°196	num_steps = 34	winner = trainer (O)
# Game n°197	num_steps = 12	winner = trainer (O)
# Game n°198	num_steps = 31	winner = learner (X)
# Game n°199	num_steps = 8	winner = learner (O)
# Game n°200	num_steps = 13	winner = learner (X)
#
# [AI] symbol = O
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# [Players X vs. O] winrate = 0.62 (over 200 games)
#
# [Learner vs. Trainer] winrate = 0.46 (over 200 games)
#
# {'draw': 2, ('learner', 'X'): 57, ('learner', 'O'): 34, ('trainer', 'X'): 66, ('trainer', 'O'): 41}
# {'X': 123, 'O': 75, 'draw': 2}
# {'learner': 91, 'trainer': 107, 'draw': 2}
# (True,
#  {'draw': 2,
#   ('learner', 'X'): 57,
#   ('learner', 'O'): 34,
#   ('trainer', 'X'): 66,
#   ('trainer', 'O'): 41},
#  [21,
#   21,
#   23,
#   28,
#   27,
#   11,
#   38,
#   15,
#   27,
#   18,
#   19,
#   22,
#   17,
#   15,
#   15,
#   22,
#   21,
#   27,
#   18,
#   11,
#   29,
#   17,
#   15,
#   13,
#   17,
#   18,
#   25,
#   29,
#   20,
#   33,
#   42,
#   16,
#   16,
#   25,
#   15,
#   13,
#   19,
#   13,
#   19,
#   16,
#   16,
#   17,
#   7,
#   18,
#   20,
#   17,
#   7,
#   18,
#   13,
#   25,
#   33,
#   22,
#   38,
#   21,
#   13,
#   15,
#   21,
#   15,
#   22,
#   20,
#   18,
#   13,
#   29,
#   15,
#   9,
#   13,
#   25,
#   26,
#   18,
#   23,
#   29,
#   13,
#   26,
#   20,
#   19,
#   37,
#   23,
#   17,
#   14,
#   19,
#   23,
#   25,
#   13,
#   13,
#   17,
#   24,
#   32,
#   22,
#   21,
#   15,
#   17,
#   28,
#   15,
#   19,
#   18,
#   26,
#   31,
#   22,
#   26,
#   15,
#   25,
#   24,
#   16,
#   17,
#   22,
#   12,
#   18,
#   15,
#   14,
#   29,
#   36,
#   21,
#   33,
#   7,
#   21,
#   21,
#   17,
#   22,
#   17,
#   24,
#   22,
#   8,
#   32,
#   11,
#   30,
#   7,
#   7,
#   13,
#   31,
#   13,
#   33,
#   22,
#   25,
#   25,
#   17,
#   32,
#   37,
#   25,
#   21,
#   39,
#   30,
#   29,
#   27,
#   26,
#   22,
#   20,
#   7,
#   19,
#   12,
#   27,
#   15,
#   19,
#   29,
#   23,
#   34,
#   42,
#   20,
#   17,
#   34,
#   27,
#   26,
#   26,
#   22,
#   25,
#   19,
#   26,
#   24,
#   13,
#   25,
#   19,
#   21,
#   29,
#   14,
#   22,
#   16,
#   19,
#   15,
#   9,
#   22,
#   26,
#   15,
#   16,
#   20,
#   28,
#   7,
#   17,
#   7,
#   15,
#   19,
#   38,
#   23,
#   39,
#   7,
#   30,
#   28,
#   34,
#   12,
#   31,
#   8,
#   13])

# %%
# Either 'Random', 'MC' for Monte Carlo, or 'UCT' for Upper-Confidence bounds for Trees
trainer_choice = 'UCT'

# Play 200 games in a setting UCT AI vs. trainer AI
puissance4.prepare_and_train(trainer_choice=trainer_choice, num_parties_jouees=200)
# Out:
# [AI] symbol = X
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# [AI] symbol = O
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# Game n°1	num_steps = 21	winner = learner (X)
# Game n°2	num_steps = 15	winner = learner (X)
# Game n°3	num_steps = 17	winner = learner (X)
# Game n°4	num_steps = 17	winner = learner (X)
# Game n°5	num_steps = 25	winner = trainer (X)
# Game n°6	num_steps = 21	winner = learner (X)
# Game n°7	num_steps = 25	winner = trainer (X)
# Game n°8	num_steps = 21	winner = learner (X)
# Game n°9	num_steps = 15	winner = learner (X)
# Game n°10	num_steps = 15	winner = learner (X)
# Game n°11	num_steps = 15	winner = learner (X)
# Game n°12	num_steps = 21	winner = trainer (X)
# Game n°13	num_steps = 15	winner = learner (X)
# Game n°14	num_steps = 15	winner = learner (X)
# Game n°15	num_steps = 21	winner = learner (X)
# Game n°16	num_steps = 19	winner = learner (X)
# Game n°17	num_steps = 21	winner = learner (X)
# Game n°18	num_steps = 19	winner = learner (X)
# Game n°19	num_steps = 21	winner = trainer (X)
# Game n°20	num_steps = 21	winner = learner (X)
# Game n°21	num_steps = 25	winner = learner (X)
# Game n°22	num_steps = 15	winner = learner (X)
# Game n°23	num_steps = 15	winner = learner (X)
# Game n°24	num_steps = 36	winner = learner (O)
# Game n°25	num_steps = 36	winner = learner (O)
# Game n°26	num_steps = 36	winner = learner (O)
# Game n°27	num_steps = 26	winner = learner (O)
# Game n°28	num_steps = 28	winner = learner (O)
# Game n°29	num_steps = 15	winner = learner (X)
# Game n°30	num_steps = 24	winner = learner (O)
# Game n°31	num_steps = 35	winner = trainer (X)
# Game n°32	num_steps = 19	winner = learner (X)
# Game n°33	num_steps = 16	winner = learner (O)
# Game n°34	num_steps = 25	winner = learner (X)
# Game n°35	num_steps = 21	winner = learner (X)
# Game n°36	num_steps = 15	winner = learner (X)
# Game n°37	num_steps = 35	winner = trainer (X)
# Game n°38	num_steps = 35	winner = trainer (X)
# Game n°39	num_steps = 23	winner = learner (X)
# Game n°40	num_steps = 23	winner = learner (X)
# Game n°41	num_steps = 33	winner = trainer (X)
# Game n°42	num_steps = 42	winner = draw (draw)
# Game n°43	num_steps = 35	winner = trainer (X)
# Game n°44	num_steps = 33	winner = trainer (X)
# Game n°45	num_steps = 33	winner = trainer (X)
# Game n°46	num_steps = 33	winner = trainer (X)
# Game n°47	num_steps = 33	winner = trainer (X)
# Game n°48	num_steps = 33	winner = learner (X)
# Game n°49	num_steps = 32	winner = trainer (O)
# Game n°50	num_steps = 23	winner = learner (X)
# Game n°51	num_steps = 23	winner = learner (X)
# Game n°52	num_steps = 35	winner = trainer (X)
# Game n°53	num_steps = 35	winner = trainer (X)
# Game n°54	num_steps = 15	winner = learner (X)
# Game n°55	num_steps = 35	winner = trainer (X)
# Game n°56	num_steps = 39	winner = trainer (X)
# Game n°57	num_steps = 39	winner = trainer (X)
# Game n°58	num_steps = 15	winner = learner (X)
# Game n°59	num_steps = 15	winner = learner (X)
# Game n°60	num_steps = 39	winner = trainer (X)
# Game n°61	num_steps = 15	winner = learner (X)
# Game n°62	num_steps = 39	winner = trainer (X)
# Game n°63	num_steps = 37	winner = trainer (X)
# Game n°64	num_steps = 28	winner = learner (O)
# Game n°65	num_steps = 28	winner = learner (O)
# Game n°66	num_steps = 28	winner = learner (O)
# Game n°67	num_steps = 15	winner = learner (X)
# Game n°68	num_steps = 15	winner = learner (X)
# Game n°69	num_steps = 28	winner = learner (O)
# Game n°70	num_steps = 28	winner = learner (O)
# Game n°71	num_steps = 15	winner = learner (X)
# Game n°72	num_steps = 15	winner = learner (X)
# Game n°73	num_steps = 28	winner = learner (O)
# Game n°74	num_steps = 28	winner = learner (O)
# Game n°75	num_steps = 42	winner = draw (draw)
# Game n°76	num_steps = 42	winner = draw (draw)
# Game n°77	num_steps = 15	winner = learner (X)
# Game n°78	num_steps = 35	winner = trainer (X)
# Game n°79	num_steps = 15	winner = learner (X)
# Game n°80	num_steps = 37	winner = trainer (X)
# Game n°81	num_steps = 15	winner = learner (X)
# Game n°82	num_steps = 15	winner = learner (X)
# Game n°83	num_steps = 35	winner = trainer (X)
# Game n°84	num_steps = 15	winner = learner (X)
# Game n°85	num_steps = 15	winner = learner (X)
# Game n°86	num_steps = 30	winner = learner (O)
# Game n°87	num_steps = 39	winner = trainer (X)
# Game n°88	num_steps = 15	winner = learner (X)
# Game n°89	num_steps = 37	winner = trainer (X)
# Game n°90	num_steps = 37	winner = trainer (X)
# Game n°91	num_steps = 15	winner = learner (X)
# Game n°92	num_steps = 15	winner = learner (X)
# Game n°93	num_steps = 15	winner = learner (X)
# Game n°94	num_steps = 15	winner = learner (X)
# Game n°95	num_steps = 15	winner = learner (X)
# Game n°96	num_steps = 15	winner = learner (X)
# Game n°97	num_steps = 42	winner = draw (draw)
# Game n°98	num_steps = 15	winner = learner (X)
# Game n°99	num_steps = 15	winner = learner (X)
# Game n°100	num_steps = 37	winner = trainer (X)
# Game n°101	num_steps = 15	winner = learner (X)
# Game n°102	num_steps = 15	winner = learner (X)
# Game n°103	num_steps = 15	winner = learner (X)
# Game n°104	num_steps = 15	winner = learner (X)
# Game n°105	num_steps = 37	winner = trainer (X)
# Game n°106	num_steps = 37	winner = trainer (X)
# Game n°107	num_steps = 37	winner = trainer (X)
# Game n°108	num_steps = 37	winner = trainer (X)
# Game n°109	num_steps = 15	winner = learner (X)
# Game n°110	num_steps = 15	winner = learner (X)
# Game n°111	num_steps = 15	winner = learner (X)
# Game n°112	num_steps = 37	winner = trainer (X)
# Game n°113	num_steps = 37	winner = trainer (X)
# Game n°114	num_steps = 37	winner = trainer (X)
# Game n°115	num_steps = 37	winner = trainer (X)
# Game n°116	num_steps = 37	winner = trainer (X)
# Game n°117	num_steps = 37	winner = trainer (X)
# Game n°118	num_steps = 37	winner = trainer (X)
# Game n°119	num_steps = 15	winner = learner (X)
# Game n°120	num_steps = 15	winner = learner (X)
# Game n°121	num_steps = 15	winner = learner (X)
# Game n°122	num_steps = 37	winner = trainer (X)
# Game n°123	num_steps = 15	winner = learner (X)
# Game n°124	num_steps = 15	winner = learner (X)
# Game n°125	num_steps = 37	winner = trainer (X)
# Game n°126	num_steps = 37	winner = trainer (X)
# Game n°127	num_steps = 15	winner = learner (X)
# Game n°128	num_steps = 15	winner = learner (X)
# Game n°129	num_steps = 37	winner = trainer (X)
# Game n°130	num_steps = 37	winner = trainer (X)
# Game n°131	num_steps = 15	winner = learner (X)
# Game n°132	num_steps = 15	winner = learner (X)
# Game n°133	num_steps = 37	winner = trainer (X)
# Game n°134	num_steps = 37	winner = trainer (X)
# Game n°135	num_steps = 15	winner = learner (X)
# Game n°136	num_steps = 37	winner = trainer (X)
# Game n°137	num_steps = 37	winner = trainer (X)
# Game n°138	num_steps = 37	winner = trainer (X)
# Game n°139	num_steps = 15	winner = learner (X)
# Game n°140	num_steps = 15	winner = learner (X)
# Game n°141	num_steps = 15	winner = learner (X)
# Game n°142	num_steps = 37	winner = trainer (X)
# Game n°143	num_steps = 37	winner = trainer (X)
# Game n°144	num_steps = 37	winner = trainer (X)
# Game n°145	num_steps = 37	winner = trainer (X)
# Game n°146	num_steps = 15	winner = learner (X)
# Game n°147	num_steps = 15	winner = learner (X)
# Game n°148	num_steps = 37	winner = trainer (X)
# Game n°149	num_steps = 15	winner = learner (X)
# Game n°150	num_steps = 15	winner = learner (X)
# Game n°151	num_steps = 37	winner = trainer (X)
# Game n°152	num_steps = 15	winner = learner (X)
# Game n°153	num_steps = 15	winner = learner (X)
# Game n°154	num_steps = 15	winner = learner (X)
# Game n°155	num_steps = 15	winner = learner (X)
# Game n°156	num_steps = 37	winner = trainer (X)
# Game n°157	num_steps = 37	winner = trainer (X)
# Game n°158	num_steps = 15	winner = learner (X)
# Game n°159	num_steps = 37	winner = trainer (X)
# Game n°160	num_steps = 37	winner = trainer (X)
# Game n°161	num_steps = 15	winner = learner (X)
# Game n°162	num_steps = 15	winner = learner (X)
# Game n°163	num_steps = 15	winner = learner (X)
# Game n°164	num_steps = 37	winner = trainer (X)
# Game n°165	num_steps = 15	winner = learner (X)
# Game n°166	num_steps = 15	winner = learner (X)
# Game n°167	num_steps = 15	winner = learner (X)
# Game n°168	num_steps = 37	winner = trainer (X)
# Game n°169	num_steps = 37	winner = trainer (X)
# Game n°170	num_steps = 15	winner = learner (X)
# Game n°171	num_steps = 37	winner = trainer (X)
# Game n°172	num_steps = 37	winner = trainer (X)
# Game n°173	num_steps = 15	winner = learner (X)
# Game n°174	num_steps = 37	winner = trainer (X)
# Game n°175	num_steps = 37	winner = trainer (X)
# Game n°176	num_steps = 37	winner = trainer (X)
# Game n°177	num_steps = 15	winner = learner (X)
# Game n°178	num_steps = 37	winner = trainer (X)
# Game n°179	num_steps = 37	winner = trainer (X)
# Game n°180	num_steps = 15	winner = learner (X)
# Game n°181	num_steps = 15	winner = learner (X)
# Game n°182	num_steps = 15	winner = learner (X)
# Game n°183	num_steps = 15	winner = learner (X)
# Game n°184	num_steps = 37	winner = trainer (X)
# Game n°185	num_steps = 15	winner = learner (X)
# Game n°186	num_steps = 37	winner = trainer (X)
# Game n°187	num_steps = 15	winner = learner (X)
# Game n°188	num_steps = 15	winner = learner (X)
# Game n°189	num_steps = 37	winner = trainer (X)
# Game n°190	num_steps = 37	winner = trainer (X)
# Game n°191	num_steps = 37	winner = trainer (X)
# Game n°192	num_steps = 37	winner = trainer (X)
# Game n°193	num_steps = 15	winner = learner (X)
# Game n°194	num_steps = 15	winner = learner (X)
# Game n°195	num_steps = 15	winner = learner (X)
# Game n°196	num_steps = 37	winner = trainer (X)
# Game n°197	num_steps = 37	winner = trainer (X)
# Game n°198	num_steps = 37	winner = trainer (X)
# Game n°199	num_steps = 15	winner = learner (X)
# Game n°200	num_steps = 15	winner = learner (X)
#
# [AI] symbol = O
# [AI] bias to obvious steps = True
# [End-game simulations] bias to obvious steps = True
# [End-game simulations] maximal number of steps = 30
# [Monte Carlo] number of samples for grid valuation = 8
# [Upper Confidence Tree] number of tree descents = 7
# [Upper Confidence Tree] UCT factor = 0.01
#
# [Players X vs. O] winrate = 0.91 (over 200 games)
#
# [Learner vs. Trainer] winrate = 0.59 (over 200 games)
#
# {'draw': 4, ('learner', 'X'): 102, ('learner', 'O'): 15, ('trainer', 'X'): 78, ('trainer', 'O'): 1}
# {'X': 180, 'O': 16, 'draw': 4}
# {'learner': 117, 'trainer': 79, 'draw': 4}
# (True,
#  {'draw': 4,
#   ('learner', 'X'): 102,
#   ('learner', 'O'): 15,
#   ('trainer', 'X'): 78,
#   ('trainer', 'O'): 1},
#  [21,
#   15,
#   17,
#   17,
#   25,
#   21,
#   25,
#   21,
#   15,
#   15,
#   15,
#   21,
#   15,
#   15,
#   21,
#   19,
#   21,
#   19,
#   21,
#   21,
#   25,
#   15,
#   15,
#   36,
#   36,
#   36,
#   26,
#   28,
#   15,
#   24,
#   35,
#   19,
#   16,
#   25,
#   21,
#   15,
#   35,
#   35,
#   23,
#   23,
#   33,
#   42,
#   35,
#   33,
#   33,
#   33,
#   33,
#   33,
#   32,
#   23,
#   23,
#   35,
#   35,
#   15,
#   35,
#   39,
#   39,
#   15,
#   15,
#   39,
#   15,
#   39,
#   37,
#   28,
#   28,
#   28,
#   15,
#   15,
#   28,
#   28,
#   15,
#   15,
#   28,
#   28,
#   42,
#   42,
#   15,
#   35,
#   15,
#   37,
#   15,
#   15,
#   35,
#   15,
#   15,
#   30,
#   39,
#   15,
#   37,
#   37,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   42,
#   15,
#   15,
#   37,
#   15,
#   15,
#   15,
#   15,
#   37,
#   37,
#   37,
#   37,
#   15,
#   15,
#   15,
#   37,
#   37,
#   37,
#   37,
#   37,
#   37,
#   37,
#   15,
#   15,
#   15,
#   37,
#   15,
#   15,
#   37,
#   37,
#   15,
#   15,
#   37,
#   37,
#   15,
#   15,
#   37,
#   37,
#   15,
#   37,
#   37,
#   37,
#   15,
#   15,
#   15,
#   37,
#   37,
#   37,
#   37,
#   15,
#   15,
#   37,
#   15,
#   15,
#   37,
#   15,
#   15,
#   15,
#   15,
#   37,
#   37,
#   15,
#   37,
#   37,
#   15,
#   15,
#   15,
#   37,
#   15,
#   15,
#   15,
#   37,
#   37,
#   15,
#   37,
#   37,
#   15,
#   37,
#   37,
#   37,
#   15,
#   37,
#   37,
#   15,
#   15,
#   15,
#   15,
#   37,
#   15,
#   37,
#   15,
#   15,
#   37,
#   37,
#   37,
#   37,
#   15,
#   15,
#   15,
#   37,
#   37,
#   37,
#   15,
#   15])
